# %% [markdown]
# # AILAB_splitter Dataset Stats

# %%
import pandas as pd
import re

# %%
DATA_PATH = '/mnt/nas/victor_splitter/data/104pecas/uniao_104_ailab.parquet.gzip'
TRAIN_LABEL_PATH = '/mnt/nas/victor_splitter/data/104pecas/uniao_104_ailab.train'
TEST_LABEL_PATH = '/mnt/nas/victor_splitter/data/104pecas/uniao_104_ailab.val'

# %%
df_train = pd.read_csv(TRAIN_LABEL_PATH, sep=';', skiprows=0, low_memory=False)
df_test = pd.read_csv(TEST_LABEL_PATH,sep=';', skiprows=0, low_memory=False)

# %%
data_df = pd.read_parquet(DATA_PATH)

# %%
df_train = pd.merge(df_train,
                 data_df[['path', 'page', 'img']],
                 left_on='page_name', 
                 how='left', 
                 right_index=True)

# %%
df_test = pd.merge(df_test,
                 data_df[['path', 'page', 'img']],
                 left_on='page_name', 
                 how='left', 
                 right_index=True)

# %%
len(df_train), len(df_test)
# Out:
# (25694, 6095)

# %%
len(df_train)+ len(df_test)
# Out:
# 31789

# %%
del data_df

# %%
def get_extended_class(x):
    last_class = x['last_class']
    target_class = x['class']
    next_class = x['next_class']
    
    if target_class == 'FirstPage':
        if next_class == 'FirstPage': 
            x['extended_class'] = 'single page'
            return x
        else:
            x['extended_class'] = 'first of many'
        return x
    elif target_class == 'NextPage':
        if next_class == 'NextPage': 
            x['extended_class'] = 'middle'
            return x
        else:
            x['extended_class'] = 'last page'
        return x
    
def get_doc_ids (df):    
    doc_ids = []
    suffix = 1
    for index in range (len(df)):
        row = df.iloc[index]
        if row['extended_class'] == 'single page' or row['extended_class'] == 'first of many':
            suffix += 1
        doc_ids.append(row['path'][:-4] + '_'+ str(suffix))        
    return doc_ids

def add_extended_class_column(df):
    unk_class = pd.Series(['UNK'])
    last_class = unk_class.append(df['class'].iloc[:-1], ignore_index=True)
    df['last_class'] = last_class.values   

    next_class = df['class'].iloc[1:]
    next_class = next_class.append(unk_class, ignore_index=True)
    df['next_class'] = next_class.values    
    df = df.apply(get_extended_class, axis=1)
    
    df['doc_id'] = get_doc_ids(df)
    return df.copy()

# %% [markdown]
# # Volume Sample to Valid

# %%
s1 = df_train.page_name
s2 = df_test.page_name
list(set(s1).intersection(set(s2)))
# Out:
# []

# %% [markdown]
# ## Fixing Same Lawsuits Presence in Train and Test Split

# %% [markdown]
# ### Set Lawsuits for each row in splits

# %%
def add_lawsuit_column(row):
    page_name = row['page_name']
    match = re.match(r"^([A-Z]+_\d+)_.*$", page_name)
    if match:
        row['lawsuit'] = match[1]
    else:
        row['lawsuit'] = 'UNK'
    return row

# %%
df_test = df_test.apply(add_lawsuit_column, axis=1)
df_train = df_train.apply(add_lawsuit_column, axis=1)

# %%
df_train = add_extended_class_column(df_train)
df_test = add_extended_class_column(df_test)

# %% [markdown]
# ### Highlight lawsuit intersections

# %%
s1 = df_train.lawsuit
s2 = df_test.lawsuit
interctions = list(set(s1).intersection(set(s2)))

# %%
interctions[-10:]
# Out:
# ['ARE_1222128',
#  'ARE_1222527',
#  'ARE_1223927',
#  'ARE_1225968',
#  'ARE_1225752',
#  'ARE_1231854',
#  'ARE_1233093',
#  'ARE_1224103',
#  'ARE_1229112',
#  'ARE_1223636']

# %% [markdown]
# #### Show amount of pages and percentage wro intersection

# %%
len(df_train[df_train['lawsuit'].isin(interctions)]),len(df_train),len(df_train[df_train['lawsuit'].isin(interctions)])/len(df_train)
# Out:
# (5230, 25694, 0.20354946680158792)

# %%
len(df_test[df_test['lawsuit'].isin(interctions)]),len(df_test),len(df_test[df_test['lawsuit'].isin(interctions)])/len(df_test)
# Out:
# (1277, 6095, 0.2095159967186218)

# %% [markdown]
# ### Get the amount of pages for each lawsuit in the splits

# %%
test_lawsuits_counter = df_test[df_test['lawsuit'].isin(interctions)].lawsuit.value_counts(); test_lawsuits_counter
# Out:
# ARE_1221810    164
# ARE_1222758     75
# ARE_1223751     58
# AI_868292       48
# ARE_1222527     45
#               ...
# ARE_1226310      1
# RE_1194423       1
# ARE_1223878      1
# ARE_1223877      1
# ARE_1223649      1
# Name: lawsuit, Length: 104, dtype: int64

# %%
train_lawsuits_counter = df_train[df_train['lawsuit'].isin(interctions)].lawsuit.value_counts(); train_lawsuits_counter
# Out:
# ARE_1221810    1227
# ARE_1223112     549
# ARE_1226572     204
# ARE_1222901     150
# ARE_1221963     140
#                ...
# ARE_1235684       1
# ARE_1223877       1
# ARE_1223878       1
# ARE_1223486       1
# ARE_1223998       1
# Name: lawsuit, Length: 104, dtype: int64

# %% [markdown]
# ### Get the amount of pages for each lawsuit from both splits

# %% [markdown]
# start with train

# %%
lawsuit_pages_count = {}
for key, value in train_lawsuits_counter.items():
    if lawsuit_pages_count.get(key):
        lawsuit_pages_count[key]+= value
    else:
        lawsuit_pages_count[key] = value

# %% [markdown]
# continue with test

# %%
for key, value in test_lawsuits_counter.items():
    if lawsuit_pages_count.get(key):
        lawsuit_pages_count[key]+= value
    else:
        lawsuit_pages_count[key] = value
sample = next(iter(lawsuit_pages_count))
print(sample,lawsuit_pages_count[sample])
# Out:
# ARE_1221810 1391

# %% [markdown]
# #### Generate a list to flip between train and test according to a ratio

# %%
def flip_lawsuit_samples_by_ratio(lawsuit_pages_count, ratio):
    '''
        Triage of a list of lawsuit according to their amount of pages, 
        in order to respect a process ratio between train and test
        
        Retur
    '''
    issue_train = 0
    issue_test = 0
    ratio = .8
    flip = {}
    for key, value in lawsuit_pages_count.items():
        if issue_train < 1:
            flip['train']=[key]
            issue_train+=value
            continue
        if issue_test < 1:
            flip['test']=[key]
            issue_test+=value
            continue
        if issue_train / (issue_train + issue_test) < ratio:
            #issue test
            flip['train'].append(key)
            issue_train+=value        
        else:
            #issue train
            flip['test'].append(key)
            issue_test+=value
    return flip

# %%
flip = flip_lawsuit_samples_by_ratio(lawsuit_pages_count, 0.8)

# %% [markdown]
# ## Flipping Workflow

# %%
df_train['split'] = 'train'
df_test['split'] = 'test'

# %%
stats_df = pd.concat([df_train, df_test], ignore_index=True)

# %%
print(len(df_train),len(df_test), len(stats_df))
# Out:
# 25694 6095 31789

# %%
stats_df.loc[stats_df['lawsuit'].isin(flip['train']), 'split'] = 'train'

# %%
stats_df.loc[stats_df['lawsuit'].isin(flip['test']), 'split'] = 'test'

# %%
df_test = stats_df[stats_df.split=='test']

# %%
df_train = stats_df[stats_df.split=='train']

# %%
s1 = df_train.lawsuit
s2 = df_test.lawsuit
interctions = list(set(s1).intersection(set(s2))); interctions
# Out:
# []

# %% [markdown]
# `the empty list above means that there is no lawsuit intersection between test and train`

# %% [markdown]
# ### Lets split the train/valid data

# %%
# sort raws by path and page, to make it easy to split by the end
df_train = df_train.sort_values(by=['path', 'page'], ignore_index=True)

# %%
def split_test_valid(df_train):
    print(len(df_train))
    
    ### Take one of the volume project files `ARE_1178596`
    df_val = df_train.loc[df_train['path'].str.contains("ARE_1178596")]
    df_train.drop(df_val.index, inplace=True)
    
    ### Take the 4800 tail of the train dataframe for valid
    df_val_aux = df_train.iloc[-4773:]
    df_val = df_val.append(df_val_aux, ignore_index=True)
    df_train.drop(df_val_aux.index, inplace=True)
    print(len(df_train), len(df_val))
    return df_train, df_val

# %%
df_train[['page_name','lawsuit']].iloc[-4810:-4769]
# Out:
#                              page_name    lawsuit
# 20858   RE_656286_872193_30_05082013-2  RE_656286
# 20859   RE_656286_872193_30_05082013-3  RE_656286
# 20860   RE_656286_872193_30_05082013-4  RE_656286
# 20861   RE_656286_872193_30_05082013-5  RE_656286
# 20862   RE_656286_872200_12_05082013-1  RE_656286
# 20863   RE_656286_872200_12_05082013-2  RE_656286
# 20864   RE_656286_872200_12_05082013-3  RE_656286
# 20865   RE_656286_872200_12_05082013-4  RE_656286
# 20866   RE_656286_872200_12_05082013-5  RE_656286
# 20867   RE_656286_872200_12_05082013-6  RE_656286
# 20868   RE_656286_872200_12_05082013-7  RE_656286
# 20869   RE_656286_872200_12_05082013-8  RE_656286
# 20870   RE_656286_872200_12_05082013-9  RE_656286
# 20871  RE_656286_872200_12_05082013-10  RE_656286
# 20872  RE_656286_872200_12_05082013-11  RE_656286
# 20873  RE_656286_872200_12_05082013-12  RE_656286
# 20874  RE_656286_872200_12_05082013-13  RE_656286
# 20875  RE_656286_872200_12_05082013-14  RE_656286
# 20876  RE_656286_872200_12_05082013-15  RE_656286
# 20877  RE_656286_872200_12_05082013-16  RE_656286
# 20878  RE_656286_872200_12_05082013-17  RE_656286
# 20879  RE_656286_872200_12_05082013-18  RE_656286
# 20880  RE_656286_872200_12_05082013-19  RE_656286
# 20881   RE_656604_876225_30_18052013-1  RE_656604
# 20882   RE_656604_876225_30_18052013-2  RE_656604
# 20883   RE_656604_876225_30_18052013-3  RE_656604
# 20884   RE_656604_876225_30_18052013-4  RE_656604
# 20885   RE_656604_876225_30_18052013-5  RE_656604
# 20886   RE_656619_876381_30_18052013-1  RE_656619
# 20887   RE_656619_876381_30_18052013-2  RE_656619
# 20888   RE_656619_876381_30_18052013-3  RE_656619
# 20889   RE_656619_876381_30_18052013-4  RE_656619
# 20890   RE_656619_876381_30_18052013-5  RE_656619
# 20891   RE_656619_876398_12_18052013-1  RE_656619
# 20892   RE_656619_876398_12_18052013-2  RE_656619
# 20893   RE_656619_876398_12_18052013-3  RE_656619
# 20894   RE_656619_876398_12_18052013-4  RE_656619
# 20895   RE_656619_876398_12_18052013-5  RE_656619
# 20896   RE_656619_876398_12_18052013-6  RE_656619
# 20897   RE_656619_876398_12_18052013-7  RE_656619
# 20898   RE_656619_876398_12_18052013-8  RE_656619

# %%
train_lawsuits_counter = df_train.lawsuit.value_counts(); train_lawsuits_counter
# Out:
# ARE_1221810    1391
# ARE_1106715     984
# ARE_1178596     713
# ARE_1092927     535
# ARE_1095892     424
#                ...
# RE_1234319        1
# ARE_1033191       1
# RE_1236130        1
# RE_1226564        1
# ARE_1039407       1
# Name: lawsuit, Length: 1413, dtype: int64

# %%
lawsuit_pages_count = {}
for key, value in train_lawsuits_counter.items():
    if lawsuit_pages_count.get(key):
        lawsuit_pages_count[key]+= value
    else:
        lawsuit_pages_count[key] = value

# %%
flip = flip_lawsuit_samples_by_ratio(lawsuit_pages_count, 0.9)

# %%
df_train.loc[df_train['lawsuit'].isin(flip['train']), 'split'] = 'train'

# %%
df_train.loc[df_train['lawsuit'].isin(flip['test']), 'split'] = 'valid'

# %%
df_val = df_train[df_train.split=='valid'].copy()

# %%
df_train = df_train[df_train.split=='train'].copy()

# %%
df_train.columns
# Out:
# Index(['binder', 'page_name', 'class', 'new_process', 'prev_page_name', 'path',
#        'page', 'img', 'lawsuit', 'last_class', 'next_class', 'extended_class',
#        'doc_id', 'split'],
#       dtype='object')

# %% [markdown]
# ## Stats

# %%
def print_df_stats(df):
    n_lawsuits = len(df['lawsuit'].unique())
    n_files = len(df['path'].unique())
    distro_2 = df['class'].value_counts()
    distro_4 = df['extended_class'].value_counts()
    docs = len(df['doc_id'].unique())
    total = len(df)
    print(f'#lawsuits {n_lawsuits}')
    print('\n')
    print(f'#files {n_files}')
    print('\n')
    print(f'#Docs {docs}')
    print('\n')    
    print(f'-- two classes distribution -- \n{distro_2}')
    print('\n')
    print(f'-- three classes distribution -- \n{distro_4}')
    print('\n')
    print(f'# Total pages {total}')          
    return n_lawsuits, n_files, distro_2, distro_4, docs, total

# %%
summary = [print_df_stats(df_train), print_df_stats(df_val) , print_df_stats(df_test)]
# Out:
# #lawsuits 1133
#
#
# #files 2751
#
#
# #Docs 3077
#
#
# -- two classes distribution --
# NextPage     17464
# FirstPage     3070
# Name: class, dtype: int64
#
#
# -- three classes distribution --
# middle           15545
# last page         1919
# first of many     1917
# single page       1153
# Name: extended_class, dtype: int64
#
#
# # Total pages 20534
# #lawsuits 280
#
#
# #files 642
#
#
# #Docs 1363
#
#
# -- two classes distribution --
# NextPage     3771
# FirstPage    1363
# Name: class, dtype: int64
#
#
# -- three classes distribution --
# middle           3263
# single page       854
# first of many     509
# last page         508
# Name: extended_class, dtype: int64
#
#
# # Total pages 5134
# #lawsuits 456
#
#
# #files 899
#
#
# #Docs 1063
#
#
# -- two classes distribution --
# NextPage     5067
# FirstPage    1054
# Name: class, dtype: int64
#
#
# -- three classes distribution --
# middle           4526
# last page         541
# first of many     540
# single page       514
# Name: extended_class, dtype: int64
#
#
# # Total pages 6121

# %%
stats_df = pd.concat([df_train, df_val, df_test], ignore_index=True)

# %%
print_df_stats(df_train)
# Out:
# #lawsuits 1133
#
#
# #files 2751
#
#
# #Docs 3077
#
#
# -- two classes distribution --
# NextPage     17464
# FirstPage     3070
# Name: class, dtype: int64
#
#
# -- three classes distribution --
# middle           15545
# last page         1919
# first of many     1917
# single page       1153
# Name: extended_class, dtype: int64
#
#
# # Total pages 20534
# (1133,
#  2751,
#  NextPage     17464
#  FirstPage     3070
#  Name: class, dtype: int64,
#  middle           15545
#  last page         1919
#  first of many     1917
#  single page       1153
#  Name: extended_class, dtype: int64,
#  3077,
#  20534)

# %%
col = 0
#lawsuits
print('lawsuits', summary[0][col] + summary[1][col] + summary[2][col])
col = 1
print('files ',summary[0][col] + summary[1][col] + summary[2][col])

col = 5
print('total',summary[0][col] + summary[1][col] + summary[2][col])
# Out:
# lawsuits 1869
# files  4292
# total 31789

# %%
stats_df_ds2 = stats_df.loc[stats_df['lawsuit'].str.contains("ARE_1178596|ARE_1106715|ARE_1177294")]

# %%
stats_df.loc[stats_df['lawsuit'].str.contains("ARE_1106715")]#|ARE_1178596")]#|ARE_1177294")]
# Out:
#       binder                              page_name      class new_process  \
# 22240  ailab  ARE_1106715_15339200896_60_24052019-1  FirstPage          no
# 22241  ailab  ARE_1106715_15339200896_60_24052019-2   NextPage          no
# 22242  ailab  ARE_1106715_15339200896_60_24052019-3   NextPage          no
# 22243  ailab  ARE_1106715_15339200896_60_24052019-4  FirstPage          no
# 22244  ailab  ARE_1106715_15339200896_60_24052019-5  FirstPage          no
# ...      ...                                    ...        ...         ...
# 23219  ailab  ARE_1106715_313661377_60_14022018-486  FirstPage          no
# 23220  ailab  ARE_1106715_313661377_60_14022018-487  FirstPage          no
# 23221  ailab  ARE_1106715_313661377_60_14022018-488  FirstPage          no
# 23222  ailab  ARE_1106715_313661377_60_14022018-489  FirstPage          no
# 23223  ailab  ARE_1106715_313661377_60_14022018-490  FirstPage          no
#
#                               prev_page_name  \
# 22240  ARE_1106715_313661377_60_14022018-490
# 22241  ARE_1106715_15339200896_60_24052019-1
# 22242  ARE_1106715_15339200896_60_24052019-2
# 22243  ARE_1106715_15339200896_60_24052019-3
# 22244  ARE_1106715_15339200896_60_24052019-4
# ...                                      ...
# 23219  ARE_1106715_313661377_60_14022018-485
# 23220  ARE_1106715_313661377_60_14022018-486
# 23221  ARE_1106715_313661377_60_14022018-487
# 23222  ARE_1106715_313661377_60_14022018-488
# 23223  ARE_1106715_313661377_60_14022018-489
#
#                                           path  page  \
# 22240  ARE_1106715_15339200896_60_24052019.pdf     1
# 22241  ARE_1106715_15339200896_60_24052019.pdf     2
# 22242  ARE_1106715_15339200896_60_24052019.pdf     3
# 22243  ARE_1106715_15339200896_60_24052019.pdf     4
# 22244  ARE_1106715_15339200896_60_24052019.pdf     5
# ...                                        ...   ...
# 23219    ARE_1106715_313661377_60_14022018.pdf   486
# 23220    ARE_1106715_313661377_60_14022018.pdf   487
# 23221    ARE_1106715_313661377_60_14022018.pdf   488
# 23222    ARE_1106715_313661377_60_14022018.pdf   489
# 23223    ARE_1106715_313661377_60_14022018.pdf   490
#
#                                                      img      lawsuit  \
# 22240  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAIBAQEBAQIBAQ...  ARE_1106715
# 22241  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAIBAQEBAQIBAQ...  ARE_1106715
# 22242  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAIBAQEBAQIBAQ...  ARE_1106715
# 22243  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAIBAQEBAQIBAQ...  ARE_1106715
# 22244  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAIBAQEBAQIBAQ...  ARE_1106715
# ...                                                  ...          ...
# 23219  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAIBAQEBAQIBAQ...  ARE_1106715
# 23220  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAIBAQEBAQIBAQ...  ARE_1106715
# 23221  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAIBAQEBAQIBAQ...  ARE_1106715
# 23222  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAIBAQEBAQIBAQ...  ARE_1106715
# 23223  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAIBAQEBAQIBAQ...  ARE_1106715
#
#       last_class next_class extended_class  \
# 22240  FirstPage   NextPage  first of many
# 22241  FirstPage   NextPage         middle
# 22242   NextPage  FirstPage      last page
# 22243   NextPage  FirstPage    single page
# 22244  FirstPage  FirstPage    single page
# ...          ...        ...            ...
# 23219  FirstPage  FirstPage    single page
# 23220  FirstPage  FirstPage    single page
# 23221  FirstPage  FirstPage    single page
# 23222  FirstPage  FirstPage    single page
# 23223  FirstPage  FirstPage    single page
#
#                                          doc_id  split
# 22240  ARE_1106715_15339200896_60_24052019_2252  valid
# 22241  ARE_1106715_15339200896_60_24052019_2252  valid
# 22242  ARE_1106715_15339200896_60_24052019_2252  valid
# 22243  ARE_1106715_15339200896_60_24052019_2253  valid
# 22244  ARE_1106715_15339200896_60_24052019_2254  valid
# ...                                         ...    ...
# 23219    ARE_1106715_313661377_60_14022018_2247  valid
# 23220    ARE_1106715_313661377_60_14022018_2248  valid
# 23221    ARE_1106715_313661377_60_14022018_2249  valid
# 23222    ARE_1106715_313661377_60_14022018_2250  valid
# 23223    ARE_1106715_313661377_60_14022018_2251  valid
#
# [984 rows x 14 columns]

# %%
stats_df_ds1 = stats_df.loc[~stats_df['lawsuit'].str.contains("ARE_1178596|ARE_1106715|ARE_1177294")]

# %%
stats_df_ds2
# Out:
#       binder                               page_name      class new_process  \
# 11319  ailab   ARE_1178596_15339146471_60_28112018-1   NextPage         yes
# 11320  ailab   ARE_1178596_15339146471_60_28112018-2   NextPage          no
# 11321  ailab   ARE_1178596_15339146471_60_28112018-3   NextPage          no
# 11322  ailab   ARE_1178596_15339146471_60_28112018-4   NextPage          no
# 11323  ailab   ARE_1178596_15339146471_60_28112018-5   NextPage          no
# ...      ...                                     ...        ...         ...
# 31137  ailab   ARE_1177294_15339107099_60_22112018-8  FirstPage          no
# 31138  ailab   ARE_1177294_15339107099_60_22112018-9  FirstPage          no
#                                          doc_id  split
# 14348  ARE_1178596_15339146471_60_28112018_2608  train
# 14349  ARE_1178596_15339146471_60_28112018_2608  train
# 14350  ARE_1178596_15339146471_60_28112018_2608  train
# 14351  ARE_1178596_15339146471_60_28112018_2608  train
# 14352  ARE_1178596_15339146471_60_28112018_2608  train
# ...                                         ...    ...
# 15056  ARE_1178596_15339146477_60_28112018_2906  train
# 15057  ARE_1178596_15339146477_60_28112018_2906  train
# 15058  ARE_1178596_15339146477_60_28112018_2906  train
# 15059  ARE_1178596_15339146477_60_28112018_2906  train
# 15060  ARE_1178596_15339146477_60_28112018_2906  train
#
# [713 rows x 14 columns]

# %%
print(len(df_train), len(df_val), len(df_test), len(df_train)+ len(df_val)+ len(df_test))
# Out:
# 20534 5134 6121 31789

# %%
s1 = df_train.lawsuit
s2 = df_val.lawsuit
interctions = list(set(s1).intersection(set(s2))); interctions
# Out:
# []

# %% [markdown]
# ## Export Data

# %%
EXPORT_PATH = '/mnt/nas/victor_splitter/data/isjeaai'

# %%
df_train.to_parquet(EXPORT_PATH+'/df_train.parquet.gzip',
              compression='gzip')

# %%
df_val.to_parquet(EXPORT_PATH+'/df_val.parquet.gzip',
              compression='gzip')

# %%
df_test.to_parquet(EXPORT_PATH+'/df_test.parquet.gzip',
              compression='gzip')

# %%
df_train.loc[df_train['path'].str.contains("ARE_1178596")]
# Out:
#       binder                                page_name      class new_process  \
# 14348  ailab    ARE_1178596_15339146471_60_28112018-1   NextPage         yes
# 14349  ailab    ARE_1178596_15339146471_60_28112018-2   NextPage          no
# 14350  ailab    ARE_1178596_15339146471_60_28112018-3   NextPage          no
# 14351  ailab    ARE_1178596_15339146471_60_28112018-4   NextPage          no
# 14352  ailab    ARE_1178596_15339146471_60_28112018-5   NextPage          no
# ...      ...                                      ...        ...         ...
# 15056  ailab  ARE_1178596_15339146477_60_28112018-183  FirstPage          no
# 15057  ailab  ARE_1178596_15339146477_60_28112018-184   NextPage          no
# 15058  ailab  ARE_1178596_15339146477_60_28112018-185   NextPage          no
# 15059  ailab  ARE_1178596_15339146477_60_28112018-186   NextPage          no
# 15060  ailab  ARE_1178596_15339146477_60_28112018-187   NextPage          no
#
#                                 prev_page_name  \
# 14348  ARE_1106715_15339200896_60_24052019-494
# 14349    ARE_1178596_15339146471_60_28112018-1
# 14350    ARE_1178596_15339146471_60_28112018-2
# 14351    ARE_1178596_15339146471_60_28112018-3
# 14352    ARE_1178596_15339146471_60_28112018-4
# ...                                        ...
# 15056  ARE_1178596_15339146477_60_28112018-182
# 15057  ARE_1178596_15339146477_60_28112018-183
# 15058  ARE_1178596_15339146477_60_28112018-184
# 15059  ARE_1178596_15339146477_60_28112018-185
# 15060  ARE_1178596_15339146477_60_28112018-186
#
#                                           path  page  \
# 14348  ARE_1178596_15339146471_60_28112018.pdf     1
# 14349  ARE_1178596_15339146471_60_28112018.pdf     2
# 14350  ARE_1178596_15339146471_60_28112018.pdf     3
# 23714  1225697/ARE_1225697_15340788116_0_09082019.pdf     8
# 23715  1225697/ARE_1225697_15340788137_0_09082019.pdf     1
# 23716  1225697/ARE_1225697_15340788137_0_09082019.pdf     2
# 23717  1225697/ARE_1225697_15340788137_0_09082019.pdf     3
# 23718  1225697/ARE_1225697_15340788137_0_09082019.pdf     4
# 23719  1225697/ARE_1225697_15340788137_0_09082019.pdf     5
# 23720  1225697/ARE_1225697_15340788137_0_09082019.pdf     6
# 23721  1225697/ARE_1225697_15340788137_0_09082019.pdf     7
# 23722  1225697/ARE_1225697_15340788137_0_09082019.pdf     8
# 23723  1225697/ARE_1225697_15340788137_0_09082019.pdf     9
# 23724  1225697/ARE_1225697_15340788137_0_09082019.pdf    10
# 23725  1225697/ARE_1225697_15340788137_0_09082019.pdf    11
# 23726  1225697/ARE_1225697_15340788137_0_09082019.pdf    12
# 23727  1225697/ARE_1225697_15340788137_0_09082019.pdf    13
# 23728  1225697/ARE_1225697_15340788137_0_09082019.pdf    14
# 23729  1225697/ARE_1225697_15340788137_0_09082019.pdf    15
# 23730  1225697/ARE_1225697_15340788137_0_09082019.pdf    16
# 23731  1225697/ARE_1225697_15340788137_0_09082019.pdf    17
# 23732  1225697/ARE_1225697_15340788137_0_09082019.pdf    18
# 23733  1225697/ARE_1225697_15340788137_0_09082019.pdf    19
# 23734  1225697/ARE_1225697_15340788152_0_09082019.pdf     1
#
#                                                      img      lawsuit
# 23707  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAIBAQEBAQIBAQ...  ARE_1225697
# 23708  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAIBAQEBAQIBAQ...  ARE_1225697
# 23709  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAIBAQEBAQIBAQ...  ARE_1225697
# 23710  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAIBAQEBAQIBAQ...  ARE_1225697
# 23711  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAIBAQEBAQIBAQ...  ARE_1225697
# 23712  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAIBAQEBAQIBAQ...  ARE_1225697
# 23713  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAIBAQEBAQIBAQ...  ARE_1225697
# 23714  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAIBAQEBAQIBAQ...  ARE_1225697
# 23715  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAIBAQEBAQIBAQ...  ARE_1225697
# 23716  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAIBAQEBAQIBAQ...  ARE_1225697
# 23717  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAIBAQEBAQIBAQ...  ARE_1225697
# 23718  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAIBAQEBAQIBAQ...  ARE_1225697
# 23719  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAIBAQEBAQIBAQ...  ARE_1225697
# 23720  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAIBAQEBAQIBAQ...  ARE_1225697
# 23721  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAIBAQEBAQIBAQ...  ARE_1225697
# 23722  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAIBAQEBAQIBAQ...  ARE_1225697
# 23723  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAIBAQEBAQIBAQ...  ARE_1225697
# 23724  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAIBAQEBAQIBAQ...  ARE_1225697
# 23725  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAIBAQEBAQIBAQ...  ARE_1225697
# 23726  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAIBAQEBAQIBAQ...  ARE_1225697
# 23727  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAIBAQEBAQIBAQ...  ARE_1225697
# 23728  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAIBAQEBAQIBAQ...  ARE_1225697
# 23729  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAIBAQEBAQIBAQ...  ARE_1225697
# 23730  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAIBAQEBAQIBAQ...  ARE_1225697
# 23731  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAIBAQEBAQIBAQ...  ARE_1225697
# 23732  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAIBAQEBAQIBAQ...  ARE_1225697
# 23733  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAIBAQEBAQIBAQ...  ARE_1225697
# 23734  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAIBAQEBAQIBAQ...  ARE_1225697

# %%
df_test[df_test.lawsuit=='ARE_1225697']#['path'].value_counts
# Out:
#      binder                             page_name      class new_process  \
# 5628  ailab  ARE_1225697_15340788151_0_09082019-1  FirstPage          no
# 5629  ailab  ARE_1225697_15340788153_0_09082019-1  FirstPage          no
#
#                             prev_page_name  \
# 5628  ARE_1225628_15340784554_0_09082019-2
# 5629  ARE_1225697_15340788151_0_09082019-1
#
#                                                 path  page  \
# 5628  1225697/ARE_1225697_15340788151_0_09082019.pdf     1
# 5629  1225697/ARE_1225697_15340788153_0_09082019.pdf     1
#
#                                                     img      lawsuit
# 5628  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAIBAQEBAQIBAQ...  ARE_1225697
# 5629  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAIBAQEBAQIBAQ...  ARE_1225697

# %% [markdown]
# ### Distribution

# %%
len(df_train),len(df_train)/total_pages, len(df_val), len(df_val)/total_pages, len(df_test), len(df_test)/total_pages
# Out:
# (20181,
#  0.6348422410267702,
#  5513,
#  0.17342476957438108,
#  6095,
#  0.19173298939884867)

# %%
df_train['class'].value_counts()
# Out:
# NextPage     17017
# FirstPage     3164
# Name: class, dtype: int64

# %%
df_val['class'].value_counts()
# Out:
# NextPage     4277
# FirstPage    1236
# Name: class, dtype: int64

# %%
df_test['class'].value_counts()
# Out:
# NextPage     5008
# FirstPage    1087
# Name: class, dtype: int64
